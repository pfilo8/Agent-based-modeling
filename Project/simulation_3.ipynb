# %% [markdown]
# # Smart Dynamic Vampire without reproduction

# %%
from agent.Vampire import SimpleVampire, SmartVampire, SmartDynamicVampire
from model.VampireModel import VampireModel 
import pandas as pd
import matplotlib.pyplot as plt

# %%
model = VampireModel(max_iteration = 350, food_sharing = True, vampire_type = SmartDynamicVampire)
model.run_model()

df = model.datacollector.get_model_vars_dataframe()
df.plot()
# Out:
# <AxesSubplot:>
